# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow/data/4efd68910440d330067a5bd589a664f1.csv', sep=',')

# %%
df.sort_values(by=["image"], key=lambda x: x.str[:-4].astype("int"))
# Out:
#             image  Podolampas  detritus  Chaetoceros      cyst  Hemiaulus  \
# 0       86177.jpg    0.205195 -0.038587     0.200175 -0.325730   0.065108
# 1       86178.jpg    0.255241 -0.068376     0.207290 -0.422502   0.038681
# 2       86179.jpg    0.246781 -0.079310     0.193084 -0.379505   0.047086
# 3       86180.jpg    0.222359 -0.041490     0.202854 -0.339679   0.061171
# 4       86181.jpg    0.252085 -0.084758     0.205539 -0.337097   0.061079
# ...           ...         ...       ...          ...       ...        ...
# 36993  123170.jpg    0.203988 -0.070803     0.184446 -0.325618   0.053536
# 36994  123171.jpg    0.229492 -0.074692     0.216669 -0.322716   0.064437
# 36995  123172.jpg    0.215061 -0.013412     0.219072 -0.362705   0.079168
# 36996  123173.jpg    0.220640 -0.078003     0.191893 -0.336960   0.040329
# 36997  123174.jpg    0.235191 -0.045279     0.193666 -0.334460   0.049014
#
#        lightrods      rods  Cyanobacteria  part<Crustacea  ...  diatom scale  \
# ...

# %%
df
# Out:
#        image  Podolampas  detritus  Chaetoceros      cyst  Hemiaulus  \
# 0  86177.jpg   -0.165069  0.151315    -0.346389 -0.345964  -0.276359
# 1  86178.jpg   -0.212716  0.128930    -0.466866 -0.413068  -0.293928
# 2  86179.jpg   -0.243008  0.183547    -0.435615 -0.377586  -0.285890
# 3  86180.jpg   -0.186231  0.150082    -0.365921 -0.366151  -0.282917
# 4  86181.jpg   -0.179891  0.147135    -0.368786 -0.344151  -0.278376
# 5  86182.jpg   -0.168718  0.169073    -0.344239 -0.338673  -0.281537
# 6  86183.jpg   -0.155578  0.147715    -0.404233 -0.332849  -0.308563
# 7  86184.jpg   -0.181308  0.177184    -0.327674 -0.366986  -0.280916
# 8  86185.jpg   -0.217167  0.206917    -0.395312 -0.363081  -0.299856
# 9  86186.jpg   -0.195204  0.154943    -0.351954 -0.369526  -0.351391
#
#    lightrods      rods  Cyanobacteria  part<Crustacea  ...  diatom scale  \
# 0  -0.157468  0.195237       0.146060       -0.240759  ...      0.159176
# ...

# %%
df.append({'one': 1, 'two': 2}, ignore_index=True)
# Out:
#   one two
# 0   1   2
